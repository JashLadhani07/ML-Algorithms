# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('lpa')
# Out:
# Text(0, 0.5, 'lpa')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
print(lr.predict(x_test.iloc[0].values.reshape(1,1)))
print(lr.predict(x_test.iloc[1].values.reshape(1,1)))
print(lr.predict(x_test.iloc[2].values.reshape(1,1)))
# Out:
# [3.89111601]
# [3.09324469]
# [2.38464568]
# C:\Users\ladha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\ladha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\ladha\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red') #can also use x_test
plt.xlabel('cgpa')
plt.ylabel('lpa')
# Out:
# Text(0, 0.5, 'lpa')

# %%
#y = mx + b
m = lr.coef_
b = lr.intercept_

# %%
#calculating package -> y = mx + b i.e package = m * cpga + b
m * 8.58 + b
# Out:
# array([3.89111601])
